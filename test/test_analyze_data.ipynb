# %%
# for C repositories

import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
file_path = '/home/akazad/dataset/python_perf.jsonl'

# Read the CSV file into a DataFrame
df = pd.read_json(file_path, lines=True)

# Display the first few rows of the DataFrame to check it's loaded correctly
print(df.count())

# %%
df_sampled = df[ df['func_no_tokens'] < 100]
df_sampled.to_csv('sample.csv', index=False)

# %%
df_sampled_10 = df_sampled.sample(10)
df_sampled_10
# Out:
#                 project_name  \
# 216              beqdesigner
# 431            DecodingTrust
# 212            lizmap-plugin
# 107                     tock
# 138                     YADC
# 496                 ANNarchy
# 313         forwardscoverbot
# 65                    raylab
# 360  wisconsin-breast-cancer
# 474               cc3200tool
#
#                                             commit_url  \
# 216  https://github.com/3ll3d00d/beqdesigner/commit...
# 431  https://github.com/AI-secure/DecodingTrust/com...
# 212  https://github.com/3liz/lizmap-plugin/commit/9...
# 107  https://github.com/18F/tock/commit/64d1584599d...
# 138  https://github.com/2e0byo/YADC/commit/dbe4efbe...
# 496  https://github.com/ANNarchy/ANNarchy/commit/3a...
# 313  https://github.com/91DarioDev/forwardscoverbot...
# 65   https://github.com/0xangelo/raylab/commit/0578...
# 360  https://github.com/AFAgarap/wisconsin-breast-c...
# 474  https://github.com/ALLTERCO/cc3200tool/commit/...
#
# ...
